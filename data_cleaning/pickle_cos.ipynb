# %%
import pandas as pd
import numpy as np
import os
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from scipy.spatial.distance import euclidean
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import re
import pickle

# %%
df=pd.read_csv('data/final_df.csv')
df
# Out:
#       Unnamed: 0  Unnamed: 0.1                           uniq_id  \
# 0              0             0  eac7efa5dbd3d667f26eb3d3ab504464
# 1              1             1  b17540ef7e86e461d37f3ae58b7b72ac
# 2              2             2  348f344247b0c1a935b1223072ef9d8a
# 3              3             3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4              4             4  e33a9adeed5f36840ccc227db4682a36
# ...          ...           ...                               ...
# 9995        9995          9995  44d6967f083825a5de36ad4865a65bcd
# 9996        9996          9996  08f0747b6fc6687215ffb994c3a6fb32
# 9997        9997          9997  bf6cc073f8f24e6e338190fa16f6ee9d
# 9998        9998          9998  cd783d0b8b44e631b9788b203eaaefae
# 9999        9999          9999  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9995  Batman 1966 TV Series Action Figures - The Rid...
# 9996  Star Wars Costume, Kids Stormtrooper Costume S...
# 9997        Defiance Lawkeeper Metal Badge Prop Replica
# 9998  Justice League of America Series 3 Green Lante...
# 9999                  Star Wars 1/72 Y-Wing Starfighter
#
#                  manufacturer  number_available_in_stock  number_of_reviews  \
# 0                      Hornby                          5                 15
# 1                   FunkyBuys                          0                  2
# 2                         ccf                          2                 17
# 3                      Hornby                          0                  1
# 4                      Hornby                          0                  3
# ...                       ...                        ...                ...
# 9995                   Mattel                          5                  3
# 9996                Star Wars                          0                  1
# 9997  Olde Scotland Yard Ltd.                          3                  1
# 9998                DC Comics                          3                  1
# 9999                   Bandai                         31                 11
#
#       number_of_answered_questions  average_review_rating  \
# 0                                1                    4.9
# 1                                1                    4.5
# 2                                2                    3.9
# 3                                2                    5.0
# 4                                2                    4.7
# ...                            ...                    ...
# 9995                             3                    5.0
# 9996                             3                    4.0
# 9997                             3                    5.0
# 9998                             3                    5.0
# 9999                             3                    4.5
#
#                        amazon_category_and_sub_category  ... avg_price  \
# 0     Hobbies , Model Trains & Railway Sets , Rail V...  ...      3.42
# 1     Hobbies , Model Trains & Railway Sets , Rail V...  ...     16.99
# 2     Hobbies , Model Trains & Railway Sets , Rail V...  ...      9.99
# 3     Hobbies , Model Trains & Railway Sets , Rail V...  ...     39.99
# 4     Hobbies , Model Trains & Railway Sets , Rail V...  ...     32.19
# ...                                                 ...  ...       ...
# 9995  Hobbies , Collectible Figures & Memorabilia , ...  ...     22.95
# 9996             Characters & Brands , Star Wars , Toys  ...     39.99
# 9997  Novelty & Special Use , Novelty , Accessories ...  ...     43.99
# 9998  Hobbies , Collectible Figures & Memorabilia , ...  ...     49.81
# 9999             Characters & Brands , Star Wars , Toys  ...     21.20
#
#      price_tag                                   seller_info_list  \
# 0         0-25  Amazon.co.uk,£3.42,**stop-&-shop-uk**,£0.19,Wo...
# 1         0-25                               UHD WHOLESALE,£16.99
# 2         0-25  DEAL-BOX,£9.99,DO NOT BUY - TESTING ACCOUNT,£2...
# 3        25-50                                     no_seller_info
# 4        25-50                                     no_seller_info
# ...        ...                                                ...
# 9995      0-25  Star Action Figures,£22.95,Order66ToyStore,£19...
# 9996     25-50                                     no_seller_info
# 9997     25-50  YUK,£43.99,DealsCentre,£116.50,DALY store,£124.95
# 9998     25-50  Smaller World Future,£49.81,Glendora Unique St...
# 9999      0-25                                     no_seller_info
#
#                                     product_name_tokens  \
# 0                                 Hornby,2014,Catalogue
# 1     FunkyBuys®,Large,Christmas,Holiday,Express,Fes...
# 2     CLASSIC,TOY,TRAIN,SET,TRACK,CARRIAGES,LIGHT,EN...
# 3        HORNBY,Coach,R4410A,BR,Hawksworth,Corridor,3rd
# 4     Hornby,00,Gauge,0-4-0,Gildenlow,Salt,Co,Steam,...
# ...                                                 ...
# 9995   Batman,1966,TV,Series,Action,Figures,The,Riddler
# 9996  Star,Wars,Costume,Kids,Stormtrooper,Costume,St...
# 9997        Defiance,Lawkeeper,Metal,Badge,Prop,Replica
# 9998  Justice,League,America,Series,3,Green,Lantern,...
# 9999                  Star,Wars,1/72,Y-Wing,Starfighter
#
#                                      seller_list_tokens  \
# 0     Amazon.co.uk,**stop-&-shop-uk**,World Wide Sho...
# 1                                         UHD WHOLESALE
# 2                 DEAL-BOX,DO NOT BUY - TESTING ACCOUNT
# 3                                        no_seller_info
# 4                                        no_seller_info
# ...                                                 ...
# 9995  Star Action Figures,Order66ToyStore,X-Comics G...
# 9996                                     no_seller_info
# 9997                         YUK,DealsCentre,DALY store
# 9998  Smaller World Future,Glendora Unique Store,M a...
# 9999                                     no_seller_info
#
#                                      product_info_token  \
# 0     Technical,Details,Item,Weight640,Product,Dimen...
# 1     Technical,Details,Manufacturer,recommended,age...
# 2     Technical,Details,Manufacturer,recommended,age...
# 3     Technical,Details,Item,Weight259,Product,Dimen...
# 4     Technical,Details,Item,Weight159,Product,Dimen...
# ...                                                 ...
# 9995  Technical,Details,Item,Weight136,Product,Dimen...
# 9996  Technical,Details,Additional,Information,ASINB...
# 9997  Technical,Details,Item,Weight159,Product,Dimen...
# 9998  Technical,Details,Item,Weight181,Product,Dimen...
# 9999  Technical,Details,Item,Weight299,Product,Dimen...
#
#                                         combined_tokens main_categories  \
# 0     Hornby,2014,CatalogueHobbies , Model Trains & ...         Hobbies
# 1     FunkyBuys®,Large,Christmas,Holiday,Express,Fes...         Hobbies
# 2     CLASSIC,TOY,TRAIN,SET,TRACK,CARRIAGES,LIGHT,EN...         Hobbies
# 3     HORNBY,Coach,R4410A,BR,Hawksworth,Corridor,3rd...         Hobbies
# 4     Hornby,00,Gauge,0-4-0,Gildenlow,Salt,Co,Steam,...         Hobbies
# ...                                                 ...             ...
# 9995  Batman,1966,TV,Series,Action,Figures,The,Riddl...         Hobbies
# 9996  Star,Wars,Costume,Kids,Stormtrooper,Costume,St...      Characters
# 9997  Defiance,Lawkeeper,Metal,Badge,Prop,ReplicaNov...         Novelty
# 9998  Justice,League,America,Series,3,Green,Lantern,...         Hobbies
# 9999  Star,Wars,1/72,Y-Wing,StarfighterCharacters & ...      Characters
#
#                            customer_reviews_sent_tokens summary_sentiment
# 0     ['Worth Buying For The Pictures Alone (As Ever...          positive
# 1     ['Four Stars ', ' Very happy with the communic...          positive
# 2     ['**Highly Recommended!** ', " Simple & GREAT ...          negative
# 3     ['I love it ', " I love it. Perfect with the e...          positive
# 4     ['Birthday present ', " Bought this for my Gra...          positive
# ...                                                 ...               ...
# 9995  ['Realistic ', " Very true to the Batman class...          positive
# 9996  ['... what I see my grandson us going to have ...           neutral
# 9997  ['Five Stars ', ' arrived in excellent conditi...          positive
# 9998  ['The best sculpt in a while ', ' Okay, Hal Jo...          positive
# 9999  ['Gold leader ', ' 1st class kit top marks to ...          positive
#
# [10000 rows x 25 columns]

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['combined_tokens'])
cos = cosine_similarity(X)

# %%
model = pickle.dump(open('cos_similarity.pkl','wb'))
